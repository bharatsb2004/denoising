# %% [markdown]
# <a href="https://colab.research.google.com/github/bharatsb2004/denoising/blob/main/denoise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, Concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.losses import MeanAbsoluteError
from tensorflow.keras.applications import VGG16
from skimage import io, img_as_float
from skimage.transform import resize
import numpy as np


# Load and preprocess data
def load_data():
    noisy_imgs, clean_imgs = [], []
    for i in range(1, 101):
        noisy_img = img_as_float(io.imread(f'/content/drive/MyDrive/pics/noisy_image/noisy_image{i}.jpg'))
        clean_img = img_as_float(io.imread(f'/content/drive/MyDrive/pics/clean_image/clean_image{i}.jpg'))
        # Resize and ensure 3 channels
        noisy_img = resize(noisy_img[..., :3], (256, 256), anti_aliasing=True)
        clean_img = resize(clean_img[..., :3], (256, 256), anti_aliasing=True)
        noisy_imgs.append(noisy_img)
        clean_imgs.append(clean_img)
    return np.array(noisy_imgs), np.array(clean_imgs)

def perceptual_loss(y_true, y_pred):
    return MeanAbsoluteError()(loss_model(y_true), loss_model(y_pred))

# Combined loss function
def combined_loss(y_true, y_pred):
    return 0.3 * MeanAbsoluteError()(y_true, y_pred) + 0.7 * perceptual_loss(y_true, y_pred)

# %%
# U-Net model for denoising
def build_unet_denoising_model():
    input_img = Input(shape=(256, 256, 3))
    # Encoder
    x1 = Conv2D(64, (3, 3), activation='relu', padding='same')(input_img)
    x1 = Conv2D(64, (3, 3), activation='relu', padding='same')(x1)
    p1 = MaxPooling2D((2, 2), padding='same')(x1)

    x2 = Conv2D(128, (3, 3), activation='relu', padding='same')(p1)
    x2 = Conv2D(128, (3, 3), activation='relu', padding='same')(x2)
    p2 = MaxPooling2D((2, 2), padding='same')(x2)

    # Bottleneck
    b = Conv2D(256, (3, 3), activation='relu', padding='same')(p2)
    b = Conv2D(256, (3, 3), activation='relu', padding='same')(b)

    # Decoder
    u1 = UpSampling2D((2, 2))(b)
    u1 = Concatenate()([u1, x2])
    u1 = Conv2D(128, (3, 3), activation='relu', padding='same')(u1)

    u2 = UpSampling2D((2, 2))(u1)
    u2 = Concatenate()([u2, x1])
    u2 = Conv2D(64, (3, 3), activation='relu', padding='same')(u2)

    output_img = Conv2D(3, (3, 3), activation='sigmoid', padding='same')(u2)

    model = Model(input_img, output_img)
    model.compile(optimizer=Adam(learning_rate=1e-4), loss=combined_loss)
    return model

# %%
# VGG model for perceptual loss
vgg = VGG16(include_top=False, weights='imagenet', input_shape=(256, 256, 3))
vgg.trainable = False
loss_model = Model(inputs=vgg.input, outputs=vgg.get_layer('block3_conv3').output)

# Load data
noisy_imgs, clean_imgs = load_data()

# Build and compile the model
model = build_unet_denoising_model()

# Training callbacks
callbacks = [
    EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=5, min_lr=1e-6)
]

# Train the model
model.fit(noisy_imgs, clean_imgs, epochs=100, batch_size=10, validation_split=0.1, callbacks=callbacks)
# Out:
# Epoch 1/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 9s 565ms/step - loss: 1.3081 - val_loss: 1.5245 - learning_rate: 1.0000e-04
# Epoch 2/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 427ms/step - loss: 1.3930 - val_loss: 1.5039 - learning_rate: 1.0000e-04
# Epoch 3/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 447ms/step - loss: 1.2644 - val_loss: 1.3929 - learning_rate: 1.0000e-04
# Epoch 4/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 454ms/step - loss: 1.1981 - val_loss: 1.1523 - learning_rate: 1.0000e-04
# Epoch 5/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 437ms/step - loss: 0.9536 - val_loss: 1.0216 - learning_rate: 1.0000e-04
# Epoch 6/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - loss: 0.8935 - val_loss: 0.9415 - learning_rate: 1.0000e-04
# Epoch 7/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 442ms/step - loss: 0.7649 - val_loss: 0.8639 - learning_rate: 1.0000e-04
# Epoch 8/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 440ms/step - loss: 0.7728 - val_loss: 0.8141 - learning_rate: 1.0000e-04
# Epoch 9/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 441ms/step - loss: 0.7028 - val_loss: 0.7546 - learning_rate: 1.0000e-04
# Epoch 10/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 446ms/step - loss: 0.6554 - val_loss: 0.7164 - learning_rate: 1.0000e-04
# Epoch 11/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 441ms/step - loss: 0.6157 - val_loss: 0.7003 - learning_rate: 1.0000e-04
# Epoch 12/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 440ms/step - loss: 0.6129 - val_loss: 0.6638 - learning_rate: 1.0000e-04
# Epoch 13/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 459ms/step - loss: 0.5942 - val_loss: 0.6347 - learning_rate: 1.0000e-04
# Epoch 14/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 440ms/step - loss: 0.5671 - val_loss: 0.6194 - learning_rate: 1.0000e-04
# Epoch 15/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 440ms/step - loss: 0.5375 - val_loss: 0.6060 - learning_rate: 1.0000e-04
# Epoch 16/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 441ms/step - loss: 0.5355 - val_loss: 0.6112 - learning_rate: 1.0000e-04
# Epoch 17/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 441ms/step - loss: 0.5061 - val_loss: 0.5700 - learning_rate: 1.0000e-04
# Epoch 18/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 462ms/step - loss: 0.4684 - val_loss: 0.5559 - learning_rate: 1.0000e-04
# Epoch 19/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 445ms/step - loss: 0.4587 - val_loss: 0.5341 - learning_rate: 1.0000e-04
# Epoch 20/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 445ms/step - loss: 0.4573 - val_loss: 0.5356 - learning_rate: 1.0000e-04
# Epoch 21/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 449ms/step - loss: 0.4627 - val_loss: 0.5467 - learning_rate: 1.0000e-04
# Epoch 22/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 452ms/step - loss: 0.4622 - val_loss: 0.5052 - learning_rate: 1.0000e-04
# Epoch 23/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 451ms/step - loss: 0.4307 - val_loss: 0.5134 - learning_rate: 1.0000e-04
# Epoch 24/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 456ms/step - loss: 0.4136 - val_loss: 0.4992 - learning_rate: 1.0000e-04
# Epoch 25/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 457ms/step - loss: 0.4058 - val_loss: 0.4833 - learning_rate: 1.0000e-04
# Epoch 26/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 458ms/step - loss: 0.4056 - val_loss: 0.4758 - learning_rate: 1.0000e-04
# Epoch 27/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 460ms/step - loss: 0.3992 - val_loss: 0.4939 - learning_rate: 1.0000e-04
# Epoch 28/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 462ms/step - loss: 0.3871 - val_loss: 0.4660 - learning_rate: 1.0000e-04
# Epoch 29/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 465ms/step - loss: 0.3860 - val_loss: 0.4573 - learning_rate: 1.0000e-04
# Epoch 30/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 471ms/step - loss: 0.3806 - val_loss: 0.4522 - learning_rate: 1.0000e-04
# Epoch 31/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 487ms/step - loss: 0.3833 - val_loss: 0.4830 - learning_rate: 1.0000e-04
# Epoch 32/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 476ms/step - loss: 0.3902 - val_loss: 0.4656 - learning_rate: 1.0000e-04
# Epoch 33/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 476ms/step - loss: 0.3689 - val_loss: 0.4499 - learning_rate: 1.0000e-04
# Epoch 34/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 476ms/step - loss: 0.3902 - val_loss: 0.4450 - learning_rate: 1.0000e-04
# Epoch 35/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 474ms/step - loss: 0.3796 - val_loss: 0.4436 - learning_rate: 1.0000e-04
# Epoch 36/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 466ms/step - loss: 0.3602 - val_loss: 0.4368 - learning_rate: 1.0000e-04
# Epoch 37/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 479ms/step - loss: 0.3580 - val_loss: 0.4362 - learning_rate: 1.0000e-04
# Epoch 38/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 479ms/step - loss: 0.3536 - val_loss: 0.4352 - learning_rate: 1.0000e-04
# Epoch 39/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 456ms/step - loss: 0.3527 - val_loss: 0.4490 - learning_rate: 1.0000e-04
# Epoch 40/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 455ms/step - loss: 0.3643 - val_loss: 0.4257 - learning_rate: 1.0000e-04
# Epoch 41/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 474ms/step - loss: 0.3538 - val_loss: 0.4278 - learning_rate: 1.0000e-04
# Epoch 42/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 454ms/step - loss: 0.3472 - val_loss: 0.4273 - learning_rate: 1.0000e-04
# Epoch 43/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 472ms/step - loss: 0.3540 - val_loss: 0.4255 - learning_rate: 1.0000e-04
# Epoch 44/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 462ms/step - loss: 0.3412 - val_loss: 0.4170 - learning_rate: 1.0000e-04
# Epoch 45/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 476ms/step - loss: 0.3434 - val_loss: 0.4299 - learning_rate: 1.0000e-04
# Epoch 46/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 481ms/step - loss: 0.3499 - val_loss: 0.4248 - learning_rate: 1.0000e-04
# Epoch 47/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 470ms/step - loss: 0.3327 - val_loss: 0.4358 - learning_rate: 1.0000e-04
# Epoch 48/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 470ms/step - loss: 0.3572 - val_loss: 0.4205 - learning_rate: 1.0000e-04
# Epoch 49/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 475ms/step - loss: 0.3474 - val_loss: 0.4156 - learning_rate: 1.0000e-04
# Epoch 50/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 474ms/step - loss: 0.3291 - val_loss: 0.4052 - learning_rate: 1.0000e-04
# Epoch 51/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 481ms/step - loss: 0.3477 - val_loss: 0.4023 - learning_rate: 1.0000e-04
# Epoch 52/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 486ms/step - loss: 0.3306 - val_loss: 0.4030 - learning_rate: 1.0000e-04
# Epoch 53/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 484ms/step - loss: 0.3245 - val_loss: 0.4034 - learning_rate: 1.0000e-04
# Epoch 54/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 484ms/step - loss: 0.3371 - val_loss: 0.4000 - learning_rate: 1.0000e-04
# Epoch 55/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 502ms/step - loss: 0.3242 - val_loss: 0.3963 - learning_rate: 1.0000e-04
# Epoch 56/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 497ms/step - loss: 0.3336 - val_loss: 0.3966 - learning_rate: 1.0000e-04
# Epoch 57/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 478ms/step - loss: 0.3130 - val_loss: 0.3979 - learning_rate: 1.0000e-04
# Epoch 58/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 477ms/step - loss: 0.3388 - val_loss: 0.3930 - learning_rate: 1.0000e-04
# Epoch 59/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 473ms/step - loss: 0.3270 - val_loss: 0.4074 - learning_rate: 1.0000e-04
# Epoch 60/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 470ms/step - loss: 0.3414 - val_loss: 0.4145 - learning_rate: 1.0000e-04
# Epoch 61/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 490ms/step - loss: 0.3293 - val_loss: 0.3896 - learning_rate: 1.0000e-04
# Epoch 62/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 485ms/step - loss: 0.3300 - val_loss: 0.3945 - learning_rate: 1.0000e-04
# Epoch 63/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 467ms/step - loss: 0.3231 - val_loss: 0.4209 - learning_rate: 1.0000e-04
# Epoch 64/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 488ms/step - loss: 0.3362 - val_loss: 0.3949 - learning_rate: 1.0000e-04
# Epoch 65/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 469ms/step - loss: 0.3276 - val_loss: 0.3852 - learning_rate: 1.0000e-04
# Epoch 66/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 468ms/step - loss: 0.3317 - val_loss: 0.4025 - learning_rate: 1.0000e-04
# Epoch 67/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 488ms/step - loss: 0.3202 - val_loss: 0.3834 - learning_rate: 1.0000e-04
# Epoch 68/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 473ms/step - loss: 0.3354 - val_loss: 0.3806 - learning_rate: 1.0000e-04
# Epoch 69/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 487ms/step - loss: 0.3205 - val_loss: 0.3794 - learning_rate: 1.0000e-04
# Epoch 70/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 493ms/step - loss: 0.3116 - val_loss: 0.3856 - learning_rate: 1.0000e-04
# Epoch 71/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 475ms/step - loss: 0.3241 - val_loss: 0.3846 - learning_rate: 1.0000e-04
# Epoch 72/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 476ms/step - loss: 0.3025 - val_loss: 0.3772 - learning_rate: 1.0000e-04
# Epoch 73/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 479ms/step - loss: 0.3100 - val_loss: 0.4037 - learning_rate: 1.0000e-04
# Epoch 74/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 476ms/step - loss: 0.3191 - val_loss: 0.3843 - learning_rate: 1.0000e-04
# Epoch 75/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 493ms/step - loss: 0.3210 - val_loss: 0.3814 - learning_rate: 1.0000e-04
# Epoch 76/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 475ms/step - loss: 0.3123 - val_loss: 0.3808 - learning_rate: 1.0000e-04
# Epoch 77/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 475ms/step - loss: 0.3127 - val_loss: 0.3749 - learning_rate: 1.0000e-04
# Epoch 78/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 478ms/step - loss: 0.3038 - val_loss: 0.3755 - learning_rate: 1.0000e-04
# Epoch 79/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 474ms/step - loss: 0.3024 - val_loss: 0.4128 - learning_rate: 1.0000e-04
# Epoch 80/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 473ms/step - loss: 0.3215 - val_loss: 0.3763 - learning_rate: 1.0000e-04
# Epoch 81/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 479ms/step - loss: 0.3022 - val_loss: 0.3715 - learning_rate: 1.0000e-04
# Epoch 82/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 472ms/step - loss: 0.2974 - val_loss: 0.3708 - learning_rate: 1.0000e-04
# Epoch 83/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 472ms/step - loss: 0.2958 - val_loss: 0.3715 - learning_rate: 1.0000e-04
# Epoch 84/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 473ms/step - loss: 0.3102 - val_loss: 0.3712 - learning_rate: 1.0000e-04
# Epoch 85/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 487ms/step - loss: 0.3011 - val_loss: 0.3696 - learning_rate: 1.0000e-04
# Epoch 86/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 491ms/step - loss: 0.3022 - val_loss: 0.3692 - learning_rate: 1.0000e-04
# Epoch 87/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 491ms/step - loss: 0.3016 - val_loss: 0.3724 - learning_rate: 1.0000e-04
# Epoch 88/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 473ms/step - loss: 0.3143 - val_loss: 0.3821 - learning_rate: 1.0000e-04
# Epoch 89/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 491ms/step - loss: 0.3162 - val_loss: 0.3853 - learning_rate: 1.0000e-04
# Epoch 90/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 474ms/step - loss: 0.3075 - val_loss: 0.3644 - learning_rate: 1.0000e-04
# Epoch 91/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 472ms/step - loss: 0.2850 - val_loss: 0.3646 - learning_rate: 1.0000e-04
# Epoch 92/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 473ms/step - loss: 0.3000 - val_loss: 0.3616 - learning_rate: 1.0000e-04
# Epoch 93/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 473ms/step - loss: 0.3006 - val_loss: 0.3646 - learning_rate: 1.0000e-04
# Epoch 94/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 472ms/step - loss: 0.3058 - val_loss: 0.3623 - learning_rate: 1.0000e-04
# Epoch 95/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 488ms/step - loss: 0.2946 - val_loss: 0.3624 - learning_rate: 1.0000e-04
# Epoch 96/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 473ms/step - loss: 0.2905 - val_loss: 0.3647 - learning_rate: 1.0000e-04
# Epoch 97/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 472ms/step - loss: 0.2895 - val_loss: 0.3666 - learning_rate: 1.0000e-04
# Epoch 98/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 489ms/step - loss: 0.2868 - val_loss: 0.3614 - learning_rate: 5.0000e-05
# Epoch 99/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 475ms/step - loss: 0.2909 - val_loss: 0.3593 - learning_rate: 5.0000e-05
# Epoch 100/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 474ms/step - loss: 0.2891 - val_loss: 0.3562 - learning_rate: 5.0000e-05

# %%
import matplotlib.pyplot as plt
from skimage.transform import resize  # Optional, for resizing if needed
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import img_to_array, load_img
import numpy as np
from skimage import img_as_float, io

# Load your custom image
custom_noisy_img = img_as_float(io.imread('/content/drive/MyDrive/pics/noisy_image/noisy_image118.png'))
custom_noisy_img = resize(custom_noisy_img[..., :3], (256, 256), anti_aliasing=True)
custom_noisy_img = np.expand_dims(custom_noisy_img, axis=0)  # Add batch dimension

# Predict denoised output
denoised_output = model.predict(custom_noisy_img)
denoised_output = denoised_output[0]  # Remove batch dimension

# Clip the output to be within [0, 1] to avoid any warnings during display
denoised_output = np.clip(denoised_output, 0, 1)

# Display only the denoised image
plt.figure(figsize=(6, 6))
plt.imshow(denoised_output)
plt.axis("off")
plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step

# %%
import numpy as np
from skimage.metrics import peak_signal_noise_ratio, structural_similarity
from sklearn.metrics import mean_squared_error

# Function to evaluate the model using PSNR, SSIM, and MSE
def evaluate_model(model, noisy_imgs, clean_imgs):
    psnr_values = []
    ssim_values = []
    mse_values = []

    for i in range(len(noisy_imgs)):
        # Get a sample
        noisy_sample = noisy_imgs[i]
        clean_sample = clean_imgs[i]

        # Reshape the noisy sample for prediction
        noisy_sample_batch = np.expand_dims(noisy_sample, axis=0)

        # Predict using the trained model
        denoised_sample = model.predict(noisy_sample_batch)[0]

        # Calculate PSNR
        psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)

        # Calculate MSE
        mse = mean_squared_error(clean_sample.flatten(), denoised_sample.flatten())

        # Append the results
        psnr_values.append(psnr)
        mse_values.append(mse)

    # Average values
    avg_psnr = np.mean(psnr_values)
    avg_mse = np.mean(mse_values)

    return avg_psnr, avg_mse

# Example usage
avg_psnr, avg_mse = evaluate_model(model, noisy_imgs, clean_imgs)

print(f"Average PSNR: {avg_psnr:.2f} dB")
print(f"Average MSE: {avg_mse:.4f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Average PSNR: 33.30 dB
# Average MSE: 0.0006
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
# <ipython-input-3-ca2dbdb3eb0f>:23: UserWarning: Inputs have mismatched dtype.  Setting data_range based on image_true.
#   psnr = peak_signal_noise_ratio(clean_sample, denoised_sample)
